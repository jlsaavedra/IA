# %% [markdown]
# ##Imports

# %%
import random, numpy as np

# %% [markdown]
# ##Functions

# %%
def matrix_distancias(n):
    distancias = [[0 for j in range(n)] for i in range(n)]
    for i in range(n):
        for j in range(i + 1, n):
            distancias[i][j] = distancias[j][i] = random.randint(1, 100)
    return distancias

def calcular_distancia(cities, distances):
  total_distance = 0
  for i in range(len(cities)-1):
    current_city = cities[i]
    next_city = cities[i+1]
    distance = distances[current_city-1][next_city-1]
    total_distance += distance
  return total_distance

def generar_ruta(numero_inicial, longitud):  
  ruta = [numero_inicial]
  while len(ruta) < longitud:
    numero_aleatorio = random.randint(1, longitud)
    if numero_aleatorio not in ruta:
      ruta.append(numero_aleatorio)
  return ruta

def generar_pob_rutas(numero_inicial, longitud):
  resultado = []
  while len(resultado) < longitud:
    temp = generar_ruta(numero_inicial, longitud)
    if temp not in resultado:
      resultado.append(temp)
  return resultado

def generar_ruta_bin(longitud, bin_code):
  numeros = []
  while len(numeros) < longitud * bin_code:
    numero_aleatorio = random.randint(0, 1)
    numeros.append(numero_aleatorio)
  return numeros

def generar_pob_bin(longitud, bin_code, cantidad):
  resultado = []
  while len(resultado) < cantidad:
    temp = generar_ruta_bin(longitud, bin_code)
    if temp not in resultado:
      resultado.append(temp)
  return resultado

def cotejar_bin2(ruta_actual, mi_array):
  pos_actual = 0  
  ruta_nueva = ruta_actual[:]

  for i in range(1, len(ruta_actual)):
    if mi_array[(i - 1) * 2] != mi_array[((i - 1) * 2) + 1]:
      if mi_array[(i - 1) * 2] == 0 and i + 1 < len(ruta_actual):
        temp = ruta_nueva[i]
        ruta_nueva[i] = ruta_nueva[i + 1]
        ruta_nueva[i + 1] = temp
  
  return ruta_nueva

def cotejar_bin3(ruta_actual, mi_array):
  pos_actual = 0  
  ruta_nueva = ruta_actual[:]

  for i in range(1, len(ruta_actual)):
    if mi_array[(i - 1) * 2] != mi_array[((i - 1) * 2) + 1]:
      if mi_array[(i - 1) * 2] == 0 and i + 1 < len(ruta_actual):
        temp = ruta_nueva[i]
        ruta_nueva[i] = ruta_nueva[i + 1]
        ruta_nueva[i + 1] = temp
      if mi_array[((i - 1) * 2) + 1] != mi_array[((i - 1) * 2) + 2]:
        if mi_array[((i - 1) * 2) + 1] == 0 and i + 2 < len(ruta_actual):
          temp = ruta_nueva[i]
          ruta_nueva[i] = ruta_nueva[i + 2]
          ruta_nueva[i + 2] = temp
  
  return ruta_nueva

def cruzar(parent1, parent2):
    idx1 = random.choice(range(1, len(parent1) - 1))
    idx2 = random.choice(range(1, len(parent2) - 1))
    child = [-1 for i in range(len(parent1))]
    child[idx1:idx2] = parent1[idx1:idx2]
    j = 0
    for i in range(len(child)):
        if child[i] == -1:
            while parent2[j] in child:
                j += 1
            child[i] = parent2[j]
    return child

def mutar(child):
    idx1 = random.choice(range(1, len(child) - 1))
    idx2 = random.choice(range(1, len(child) - 1))
    child[idx1], child[idx2] = child[idx2], child[idx1]
    return child

def generar_pob_cruzar(parent1, parent2, longitud, num_elite, mutation_prob):
  resultado = [parent1, parent2]
  while len(resultado) < longitud:
    temp_c = cruzar(parent1, parent2)
    if random.random() < mutation_prob:
, 32, 33, 19, 34, 28, 23, 12, 30, 17, 22, 50, 46, 26, 24, 14, 43, 38, 42, 47, 4, 21, 41, 15, 8, 18, 48, 40, 31], [1, 3, 26, 18, 23, 25, 41, 31, 4, 17, 10, 15, 28, 5, 36, 19, 34, 32, 37, 39, 43, 6, 21, 33, 40, 42, 9, 30, 44, 13, 11, 46, 50, 12, 48, 16, 49, 22, 29, 20, 7, 27, 8, 14, 45, 38, 2, 24, 35, 47], [1, 19, 21, 16, 35, 36, 49, 5, 41, 4, 6, 15, 24, 18, 17, 29, 28, 33, 30, 7, 22, 44, 10, 50, 27, 25, 13, 46, 40, 48, 32, 2, 3, 47, 11, 12, 39, 43, 45, 9, 14, 20, 38, 37, 26, 31, 8, 34, 23, 42], [1, 28, 26, 3, 17, 50, 40, 29, 23, 38, 41, 46, 19, 22, 18, 21, 31, 10, 11, 43, 12, 47, 25, 34, 16, 27, 9, 8, 35, 33, 32, 44, 39, 20, 24, 45, 30, 2, 48, 13, 6, 4, 7, 15, 5, 42, 14, 36, 49, 37], [1, 47, 44, 5, 21, 43, 6, 9, 27, 31, 49, 23, 7, 37, 16, 32, 22, 15, 20, 35, 33, 46, 10, 8, 18, 2, 11, 14, 48, 50, 29, 26, 3, 36, 39, 28, 19, 40, 30, 38, 34, 25, 4, 41, 17, 42, 12, 13, 24, 45], [1, 8, 27, 25, 36, 39, 14, 44, 50, 33, 17, 49, 16, 24, 23, 37, 7, 47, 20, 29, 6, 43, 48, 40, 35, 12, 10, 15, 19, 41, 22, 4, 34, 2, 46, 38, 30, 5, 18, 21, 45, 28, 32, 13, 42, 31, 26, 9, 3, 11], [1, 32, 5, 10, 3, 11, 24, 21, 18, 37, 30, 15, 39, 47, 33, 34, 25, 38, 50, 41, 48, 26, 8, 23, 17, 42, 9, 31, 28, 43, 29, 36, 44, 13, 40, 46, 22, 7, 4, 20, 16, 14, 19, 45, 35, 49, 12, 2, 6, 27], [1, 33, 32, 6, 23, 11, 16, 27, 25, 5, 43, 19, 37, 14, 39, 18, 50, 31, 36, 26, 40, 49, 38, 34, 48, 24, 20, 12, 28, 9, 15, 47, 8, 13, 44, 42, 46, 35, 2, 10, 22, 45, 29, 17, 7, 3, 4, 41, 21, 30]]

# %% [markdown]
# ##Travelling Salesman Problem. Genetic Algorithm.

# %%
#Inicialización
dic_costes = {}
#Convergencia
for gen in range(GENERACIONES):  
  for r in range(len(pob_rutas)):
    temp_ruta = pob_rutas[r]
    temp_distancia = calcular_distancia(ruta_inicial, distancias)
    #Evaluación
    dic_costes[temp_distancia] = {'ruta': temp_ruta}
  #Ordenar costes rutas
  temp_dic_orden = dict(sorted(dic_costes.items(), key=lambda x: x[0], reverse=False))
  #Selección de los 2 padres elites 
  temp_prime = {k: temp_dic_orden[k] for k in list(temp_dic_orden)[:NUM_ELITES]}
  if(len(temp_prime) < 2):
    clave = next(iter(temp_prime))
    valor = temp_prime[clave]
    parent1 = valor['ruta']
    parent2 = generar_ruta(CIUDAD_INICIAL, LONGITUD)
  else:
    first_two_keys = list(temp_prime.keys())[:NUM_ELITES]
    parent1 = temp_prime[first_two_keys[0]]
    parent1 = parent1['ruta']
    parent2 = temp_prime[first_two_keys[1]]
    parent2 = parent2['ruta']
  #Cruzamiento, Mutación y Reemplazo
  pob_rutas = generar_pob_cruzar(parent1, parent2, LONGITUD, NUM_ELITES, MUTAR_PROB)
#Resultados
mejor_ruta = pob_rutas[0]
mejor_coste = calcular_distancia(mejor_ruta, distancias)
print("Ruta de inicial:", ruta_inicial) 
print("Coste de ruta inicial:", calcular_distancia(ruta_inicial, distancias))
print("Mejor ruta obtenida:", mejor_ruta)
print("Coste ruta obtenida:", mejor_coste)
# Out:
# Ruta de inicial: [1, 5, 39, 20, 47, 49, 46, 38, 36, 19, 12, 28, 10, 7, 40, 6, 31, 26, 11, 18, 43, 2, 13, 17, 25, 27, 34, 15, 42, 16, 9, 33, 8, 44, 50, 14, 23, 37, 22, 32, 24, 45, 41, 4, 21, 29, 35, 3, 30, 48]
# Coste de ruta inicial: 2358
# Mejor ruta obtenida: [1, 50, 9, 15, 43, 47, 32, 38, 36, 22, 6, 21, 29, 49, 34, 33, 10, 16, 5, 31, 23, 17, 24, 28, 26, 7, 2, 39, 46, 18, 8, 44, 25, 13, 14, 3, 12, 41, 11, 42, 20, 40, 19, 27, 37, 30, 45, 35, 4, 48]
# Coste ruta obtenida: 1980

# %% [markdown]
# ##Travelling Salesman Problem. Genetic Algorithm. Binary Encoding 2

# %%
#Inicialización
bin_code = 2
dic_costes = {}
pob_bin = generar_pob_bin(LONGITUD, bin_code, LONGITUD)
#Convergencia
for gen in range(GENERACIONES):  
  for r in range(len(pob_rutas)):
    temp_ruta = pob_rutas[r]
    temp_distancia = calcular_distancia(ruta_inicial, distancias)
    #Codificación Binarios  
    for b in range(len(pob_bin)):
      temp_r = cotejar_bin2(pob_rutas[r], pob_bin[b])
      temp_d = calcular_distancia(temp_r, distancias)
      if temp_d < temp_distancia:
        temp_ruta = temp_r
        temp_distancia = temp_d
    #Evaluación
    dic_costes[temp_distancia] = {'ruta': temp_ruta}
  #Ordenar costes rutas
  temp_dic_orden = dict(sorted(dic_costes.items(), key=lambda x: x[0], reverse=False))
  #Selección de los 2 padres elites 
  temp_prime = {k: temp_dic_orden[k] for k in list(temp_dic_orden)[:NUM_ELITES]}
  if(len(temp_prime) < 2):
    clave = next(iter(temp_prime))
    valor = temp_prime[clave]
    parent1 = valor['ruta']
    parent2 = generar_ruta(CIUDAD_INICIAL, LONGITUD)
  else:
    first_two_keys = list(temp_prime.keys())[:NUM_ELITES]
    parent1 = temp_prime[first_two_keys[0]]
    parent1 = parent1['ruta']
    parent2 = temp_prime[first_two_keys[1]]
    parent2 = parent2['ruta']
  #Cruzamiento, Mutación y Reemplazo
  pob_rutas = generar_pob_cruzar(parent1, parent2, LONGITUD, NUM_ELITES, MUTAR_PROB)
#Resultados
mejor_ruta = pob_rutas[0]
mejor_coste = calcular_distancia(mejor_ruta, distancias)
print("Ruta de inicial:", ruta_inicial) 
print("Coste de ruta inicial:", calcular_distancia(ruta_inicial, distancias))
print("Mejor ruta obtenida:", mejor_ruta)
print("Coste ruta obtenida:", mejor_coste)
# Out:
# Ruta de inicial: [1, 5, 39, 20, 47, 49, 46, 38, 36, 19, 12, 28, 10, 7, 40, 6, 31, 26, 11, 18, 43, 2, 13, 17, 25, 27, 34, 15, 42, 16, 9, 33, 8, 44, 50, 14, 23, 37, 22, 32, 24, 45, 41, 4, 21, 29, 35, 3, 30, 48]
# Coste de ruta inicial: 2358
# Mejor ruta obtenida: [1, 47, 4, 36, 45, 25, 15, 29, 22, 6, 20, 34, 17, 5, 46, 16, 31, 33, 27, 30, 24, 28, 23, 10, 26, 7, 18, 39, 2, 8, 13, 44, 14, 9, 41, 3, 12, 42, 11, 49, 21, 43, 40, 38, 32, 37, 35, 48, 19, 50]
# Coste ruta obtenida: 807

# %% [markdown]
# ##Travelling Salesman Problem. Genetic Algorithm. Binary Encoding 3

# %%
#Inicialización
bin_code = 3
dic_costes = {}
pob_bin = generar_pob_bin(LONGITUD, bin_code, LONGITUD)
#Convergencia
for gen in range(GENERACIONES):  
  for r in range(len(pob_rutas)):
    temp_ruta = pob_rutas[r]
    temp_distancia = calcular_distancia(ruta_inicial, distancias)
    #Codificación Binarios  
    for b in range(len(pob_bin)):
      temp_r = cotejar_bin3(pob_rutas[r], pob_bin[b])
      temp_d = calcular_distancia(temp_r, distancias)
      if temp_d < temp_distancia:
        temp_ruta = temp_r
        temp_distancia = temp_d
    #Evaluación
    dic_costes[temp_distancia] = {'ruta': temp_ruta}
  #Ordenar costes rutas
  temp_dic_orden = dict(sorted(dic_costes.items(), key=lambda x: x[0], reverse=False))
  #Selección de los 2 padres elites 
  temp_prime = {k: temp_dic_orden[k] for k in list(temp_dic_orden)[:NUM_ELITES]}
  if(len(temp_prime) < 2):
    clave = next(iter(temp_prime))
    valor = temp_prime[clave]
    parent1 = valor['ruta']
    parent2 = generar_ruta(CIUDAD_INICIAL, LONGITUD)
  else:
    first_two_keys = list(temp_prime.keys())[:NUM_ELITES]
    parent1 = temp_prime[first_two_keys[0]]
    parent1 = parent1['ruta']
    parent2 = temp_prime[first_two_keys[1]]
    parent2 = parent2['ruta']
  #Cruzamiento, Mutación y Reemplazo
  pob_rutas = generar_pob_cruzar(parent1, parent2, LONGITUD, NUM_ELITES, MUTAR_PROB)
#Resultados
mejor_ruta = pob_rutas[0]
mejor_coste = calcular_distancia(mejor_ruta, distancias)
print("Ruta de inicial:", ruta_inicial)
print("Coste de ruta inicial:", calcular_distancia(ruta_inicial, distancias))
print("Mejor ruta obtenida:", mejor_ruta)
print("Coste ruta obtenida:", mejor_coste)
# Out:
# Ruta de inicial: [1, 5, 39, 20, 47, 49, 46, 38, 36, 19, 12, 28, 10, 7, 40, 6, 31, 26, 11, 18, 43, 2, 13, 17, 25, 27, 34, 15, 42, 16, 9, 33, 8, 44, 50, 14, 23, 37, 22, 32, 24, 45, 41, 4, 21, 29, 35, 3, 30, 48]
# Coste de ruta inicial: 2358
# Mejor ruta obtenida: [1, 25, 45, 15, 36, 4, 6, 40, 29, 20, 34, 17, 5, 46, 22, 16, 24, 30, 47, 28, 27, 23, 26, 10, 7, 19, 39, 8, 2, 3, 44, 14, 13, 18, 9, 41, 12, 42, 48, 11, 43, 31, 49, 21, 38, 32, 33, 35, 37, 50]
# Coste ruta obtenida: 1090
